# %% [markdown]
# This will be the firs test for git to see if it updates in the repository.

# %% [markdown]
# This is the second line of code that I am tracking

# %% [markdown]
# Update 3

# %%
#This would be the code for this file if everything went well
